# %%
import cocoex
import pickle
from pathlib import Path
import copy
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import numpy as np

# %%
data_dir = Path("/Users/leekaijen/t7ssd/dim2feat/")

ela_files_dict = {
    "cma_random_25" : data_dir / "cma_random_25_ela.pkl",
    "cma_random_50" : data_dir / "cma_random_50_ela.pkl",
    "cma_random_75" : data_dir / "cma_random_75_ela.pkl",
    "cma_random_100" : data_dir / "cma_random_100_ela.pkl",
    "ilhs_25" : data_dir / "ilhs_25_ela.pkl",
    "ilhs_50" : data_dir / "ilhs_50_ela.pkl",
    "ilhs_75" : data_dir / "ilhs_75_ela.pkl",
    "ilhs_100" : data_dir / "ilhs_100_ela.pkl",
    "lhs_25" : data_dir / "lhs_25_ela.pkl",
    "lhs_50" : data_dir / "lhs_50_ela.pkl",
    "lhs_75" : data_dir / "lhs_75_ela.pkl",
    "lhs_100" : data_dir / "lhs_100_ela.pkl",
    "sobol_25" : data_dir / "sobol_25_ela.pkl",
    "sobol_50" : data_dir / "sobol_50_ela.pkl",
    "sobol_75" : data_dir / "sobol_75_ela.pkl",
    "sobol_100" : data_dir / "sobol_100_ela.pkl",
    "uniform_25" : data_dir / "uniform_25_ela.pkl",
    "uniform_50" : data_dir / "uniform_50_ela.pkl",
    "uniform_75" : data_dir / "uniform_75_ela.pkl",
    "uniform_100" : data_dir / "uniform_100_ela.pkl",
}

# %% [markdown]
# ## Pickle File Structure

# %%
with(open(ela_files_dict["cma_random_25"], "rb")) as f:
    data = pickle.load(f)

# %%
# Keys (function, instance, dimension)
ela_feature_keys = data[(1,1,2)].keys()
ela_feature_keys
# Out:
# dict_keys(['ela_dist', 'levelset', 'meta', 'disp', 'ic', 'nbc'])

# %%
ela_dist_keys = data[(1,1,2)]["ela_dist"][0].keys()
ela_dist_keys
# Out:
# dict_keys(['ela_distr.skewness', 'ela_distr.kurtosis', 'ela_distr.number_of_peaks', 'ela_distr.costs_runtime'])

# %%
ela_levelset_keys = data[(1,1,2)]["levelset"][0].keys()
ela_levelset_keys
# Out:
# dict_keys(['ela_level.mmce_lda_10', 'ela_level.mmce_qda_10', 'ela_level.lda_qda_10', 'ela_level.mmce_lda_25', 'ela_level.mmce_qda_25', 'ela_level.lda_qda_25', 'ela_level.mmce_lda_50', 'ela_level.mmce_qda_50', 'ela_level.lda_qda_50', 'ela_level.costs_runtime'])

# %%
ela_meta_keys = data[(1,1,2)]["meta"][0].keys()
ela_meta_keys
# Out:
# dict_keys(['ela_meta.lin_simple.adj_r2', 'ela_meta.lin_simple.intercept', 'ela_meta.lin_simple.coef.min', 'ela_meta.lin_simple.coef.max', 'ela_meta.lin_simple.coef.max_by_min', 'ela_meta.lin_w_interact.adj_r2', 'ela_meta.quad_simple.adj_r2', 'ela_meta.quad_simple.cond', 'ela_meta.quad_w_interact.adj_r2', 'ela_meta.costs_runtime'])

# %%
ela_disp_keys = data[(1,1,2)]["disp"][0].keys()
ela_disp_keys
# Out:
# dict_keys(['disp.ratio_mean_02', 'disp.ratio_mean_05', 'disp.ratio_mean_10', 'disp.ratio_mean_25', 'disp.ratio_median_02', 'disp.ratio_median_05', 'disp.ratio_median_10', 'disp.ratio_median_25', 'disp.diff_mean_02', 'disp.diff_mean_05', 'disp.diff_mean_10', 'disp.diff_mean_25', 'disp.diff_median_02', 'disp.diff_median_05', 'disp.diff_median_10', 'disp.diff_median_25', 'disp.costs_runtime'])

# %%
nbc_keys = data[(1,1,2)]["nbc"][0].keys()
nbc_keys
# Out:
# dict_keys(['nbc.nn_nb.sd_ratio', 'nbc.nn_nb.mean_ratio', 'nbc.nn_nb.cor', 'nbc.dist_ratio.coeff_var', 'nbc.nb_fitness.cor', 'nbc.costs_runtime'])

# %%
ic_keys = data[(1,1,2)]["ic"][0].keys()
ic_keys
# Out:
# dict_keys(['ic.h_max', 'ic.eps_s', 'ic.eps_max', 'ic.eps_ratio', 'ic.m0', 'ic.costs_runtime'])

# %% [markdown]
# ## ELA Features NANs

# %%
dim = 2
current_case = "cma_random_25"
current_run = (1,1,dim)
current_data_dir = ela_files_dict[current_case]

with open(current_data_dir, "rb") as f:
    current_dataset = pickle.load(f)

nan_dict_base = {}
for current_feat in ela_feature_keys:
    print(f"# {current_feat}")
    for key in current_dataset[current_run][current_feat][0].keys():
        print(f"{key}: {current_dataset[current_run][current_feat][0][key]}")
        nan_dict_base[key] = {"nan": [], "inf":[]}
    print()
# Out:
# # ela_dist
# ela_distr.skewness: 2.5610967371437607
# ela_distr.kurtosis: 6.276983536288876
# ela_distr.number_of_peaks: 3
# ela_distr.costs_runtime: 0.029936
#
# # levelset
# ela_level.mmce_lda_10: 0.1
# ela_level.mmce_qda_10: 0.12
# ela_level.lda_qda_10: 0.8333333333333334
# ela_level.mmce_lda_25: 0.255
# ela_level.mmce_qda_25: 0.045
# ela_level.lda_qda_25: 5.666666666666667
# ela_level.mmce_lda_50: 0.3
# ela_level.mmce_qda_50: 0.03
# ela_level.lda_qda_50: 10.0
# ela_level.costs_runtime: 0.109095
#
# # meta
# ela_meta.lin_simple.adj_r2: 0.6162267896608287
# ela_meta.lin_simple.intercept: 83.40679132988767
# ela_meta.lin_simple.coef.min: 2.4899843185138764
# ela_meta.lin_simple.coef.max: 2.754651444485341
# ela_meta.lin_simple.coef.max_by_min: 1.1062926878709938
# ela_meta.lin_w_interact.adj_r2: 0.7554172345017219
# ela_meta.quad_simple.adj_r2: 1.0
# ela_meta.quad_simple.cond: 1.0000000000000007
# ela_meta.quad_w_interact.adj_r2: 1.0
# ela_meta.costs_runtime: 0.009768
#
# # disp
# disp.ratio_mean_02: 0.002714899629534495
# disp.ratio_mean_05: 0.0033543919540820746
# disp.ratio_mean_10: 0.0046757320658843676
# disp.ratio_mean_25: 0.008633491235342385
# disp.ratio_median_02: 0.007250668137308485
# disp.ratio_median_05: 0.008895638510063558
# disp.ratio_median_10: 0.011066229581671631
# disp.ratio_median_25: 0.01971922066747794
# disp.diff_mean_02: -1.6359668800895062
# disp.diff_mean_05: -1.6349178437982363
# disp.diff_mean_10: -1.6327502904482072
# disp.diff_mean_25: -1.6262579013428262
# disp.diff_median_02: -0.6465259278393621
# disp.diff_median_05: -0.6454546443215801
# disp.diff_median_10: -0.644041051422053
# disp.diff_median_25: -0.6384058090594721
# disp.costs_runtime: 0.003143
#
# # ic
# ic.h_max: 0.6320787679311825
# ic.eps_s: 1.0060060060060056
# ic.eps_max: 0.012393912985092367
# ic.eps_ratio: -0.8958958958958956
# ic.m0: 0.398989898989899
# ic.costs_runtime: 0.415884
#
# # nbc
# nbc.nn_nb.sd_ratio: 0.8733218958530558
# nbc.nn_nb.mean_ratio: 0.8101559485803452
# nbc.nn_nb.cor: 0.9408339913144367
# nbc.dist_ratio.coeff_var: 0.3017708781174722
# nbc.nb_fitness.cor: -0.15250898051353184
# nbc.costs_runtime: 0.030719

# %%
nan_dict_base
# Out:
# {'ela_distr.skewness': {'nan': [], 'inf': []},
#  'ela_distr.kurtosis': {'nan': [], 'inf': []},
#  'ela_distr.number_of_peaks': {'nan': [], 'inf': []},
#  'ela_distr.costs_runtime': {'nan': [], 'inf': []},
#  'ela_level.mmce_lda_10': {'nan': [], 'inf': []},
#  'ela_level.mmce_qda_10': {'nan': [], 'inf': []},
#  'ela_level.lda_qda_10': {'nan': [], 'inf': []},
#  'ela_level.mmce_lda_25': {'nan': [], 'inf': []},
#  'ela_level.mmce_qda_25': {'nan': [], 'inf': []},
#  'ela_level.lda_qda_25': {'nan': [], 'inf': []},
#  'ela_level.mmce_lda_50': {'nan': [], 'inf': []},
#  'ela_level.mmce_qda_50': {'nan': [], 'inf': []},
#  'ela_level.lda_qda_50': {'nan': [], 'inf': []},
#  'ela_level.costs_runtime': {'nan': [], 'inf': []},
#  'ela_meta.lin_simple.adj_r2': {'nan': [], 'inf': []},
#  'ela_meta.lin_simple.intercept': {'nan': [], 'inf': []},
#  'ela_meta.lin_simple.coef.min': {'nan': [], 'inf': []},
#  'ela_meta.lin_simple.coef.max': {'nan': [], 'inf': []},
#  'ela_meta.lin_simple.coef.max_by_min': {'nan': [], 'inf': []},
#  'ela_meta.lin_w_interact.adj_r2': {'nan': [], 'inf': []},
#  'ela_meta.quad_simple.adj_r2': {'nan': [], 'inf': []},
#  'ela_meta.quad_simple.cond': {'nan': [], 'inf': []},
#  'ela_meta.quad_w_interact.adj_r2': {'nan': [], 'inf': []},
#  'ela_meta.costs_runtime': {'nan': [], 'inf': []},
#  'disp.ratio_mean_02': {'nan': [], 'inf': []},
#  'disp.ratio_mean_05': {'nan': [], 'inf': []},
#  'disp.ratio_mean_10': {'nan': [], 'inf': []},
#  'disp.ratio_mean_25': {'nan': [], 'inf': []},
#  'disp.ratio_median_02': {'nan': [], 'inf': []},
#  'disp.ratio_median_05': {'nan': [], 'inf': []},
#  'disp.ratio_median_10': {'nan': [], 'inf': []},
#  'disp.ratio_median_25': {'nan': [], 'inf': []},
#  'disp.diff_mean_02': {'nan': [], 'inf': []},
#  'disp.diff_mean_05': {'nan': [], 'inf': []},
#  'disp.diff_mean_10': {'nan': [], 'inf': []},
#  'disp.diff_mean_25': {'nan': [], 'inf': []},
#  'disp.diff_median_02': {'nan': [], 'inf': []},
#  'disp.diff_median_05': {'nan': [], 'inf': []},
#  'disp.diff_median_10': {'nan': [], 'inf': []},
#  'disp.diff_median_25': {'nan': [], 'inf': []},
#  'disp.costs_runtime': {'nan': [], 'inf': []},
#  'ic.h_max': {'nan': [], 'inf': []},
#  'ic.eps_s': {'nan': [], 'inf': []},
#  'ic.eps_max': {'nan': [], 'inf': []},
#  'ic.eps_ratio': {'nan': [], 'inf': []},
#  'ic.m0': {'nan': [], 'inf': []},
#  'ic.costs_runtime': {'nan': [], 'inf': []},
#  'nbc.nn_nb.sd_ratio': {'nan': [], 'inf': []},
#  'nbc.nn_nb.mean_ratio': {'nan': [], 'inf': []},
#  'nbc.nn_nb.cor': {'nan': [], 'inf': []},
#  'nbc.dist_ratio.coeff_var': {'nan': [], 'inf': []},
#  'nbc.nb_fitness.cor': {'nan': [], 'inf': []},
#  'nbc.costs_runtime': {'nan': [], 'inf': []}}

# %%
def get_ela_invalid(current_dataset, dim=2):
    current_nan = copy.deepcopy(nan_dict_base)
    levelset_failed = []
    for function in range(1,25):
        for instance in range(1,101):
            current_run = (function,instance,dim)
            for current_feat in ela_feature_keys:
                for run_num in range(30):
                    if current_feat == "levelset" and len( current_dataset[current_run][current_feat][run_num]) == 0:
                        levelset_failed.append(current_run + (run_num,))
                        continue
                    for key in current_dataset[current_run][current_feat][run_num].keys():
                        val = current_dataset[current_run][current_feat][run_num][key]
                        if np.isnan(val):
                            current_nan[key]["nan"].append(current_run + (run_num,))
                        elif np.isinf(val):
                            current_nan[key]["inf"].append(current_run + (run_num,))
    affected_keys = {k for k,v in current_nan.items() if k != "levelset_failed" and v['nan'] or v['inf']}
    filtered = {k: v for k, v in current_nan.items() if  k != "levelset_failed" and v['nan'] or v['inf']}
    return affected_keys, filtered, levelset_failed

# %%
dim = 2
current_case = "cma_random_25"
current_run = (1,1,dim)
current_data_dir = ela_files_dict[current_case]

with open(current_data_dir, "rb") as f:
    current_dataset = pickle.load(f)

affected_keys, filtered, _ = get_ela_invalid(current_dataset, dim)
affected_keys
# Out:
# {'ela_level.lda_qda_10',
#  'ela_level.lda_qda_25',
#  'ela_meta.quad_simple.cond',
#  'ic.eps_ratio'}

# %%
nan_summary = {}
set_overall = set()
for settings in ela_files_dict.keys():
    print(f"Case: {settings}")
    with open(ela_files_dict[settings], "rb") as f:
        current_dataset = pickle.load(f)
    affected_keys, filtered, failed_levelset = get_ela_invalid(current_dataset, dim)
    set_overall.update(affected_keys)
    print(f"Affected Keys: {affected_keys}, Failed Levelset: {len(failed_levelset)}")
    nan_summary[settings] = {"affected_keys": affected_keys, "filtered": filtered, "failed_levelset": failed_levelset}
    print()

print(f"Overall Affected Keys: {set_overall}")
# Out:
# Case: cma_random_25
# Affected Keys: {'ela_level.lda_qda_25', 'ela_level.lda_qda_10', 'ic.eps_ratio', 'ela_meta.quad_simple.cond'}, Failed Levelset: 981
#
# Case: cma_random_50
# Affected Keys: {'ela_level.lda_qda_25', 'ela_level.lda_qda_10', 'ic.eps_ratio', 'ela_meta.quad_simple.cond'}, Failed Levelset: 981
#
# Case: cma_random_75
# Affected Keys: {'ela_level.lda_qda_25', 'ela_level.lda_qda_10', 'ic.eps_ratio', 'ela_meta.quad_simple.cond'}, Failed Levelset: 981
#
# Case: cma_random_100
# Affected Keys: {'ela_level.lda_qda_25', 'ela_level.lda_qda_10', 'ic.eps_ratio', 'ela_meta.quad_simple.cond'}, Failed Levelset: 981
#
# Case: ilhs_25
# Affected Keys: {'disp.diff_median_02', 'disp.ratio_median_02', 'ela_level.lda_qda_50', 'ela_level.lda_qda_25', 'disp.ratio_mean_02', 'disp.diff_mean_02', 'ela_level.lda_qda_10', 'ela_meta.quad_simple.cond'}, Failed Levelset: 117
#
# Case: ilhs_50
# Affected Keys: {'ela_level.lda_qda_25', 'ela_level.lda_qda_50', 'ela_level.lda_qda_10', 'ela_meta.quad_simple.cond'}, Failed Levelset: 0
#
# Case: ilhs_75
# Affected Keys: {'ela_level.lda_qda_25', 'ela_level.lda_qda_50', 'ela_level.lda_qda_10', 'ela_meta.quad_simple.cond'}, Failed Levelset: 0
#
# Case: ilhs_100
# Affected Keys: {'ela_level.lda_qda_25', 'ela_level.lda_qda_50', 'ela_level.lda_qda_10', 'ela_meta.quad_simple.cond'}, Failed Levelset: 0
#
# Case: lhs_25
# Affected Keys: {'disp.diff_median_02', 'disp.ratio_median_02', 'ela_level.lda_qda_50', 'ela_level.lda_qda_25', 'disp.ratio_mean_02', 'disp.diff_mean_02', 'ela_level.lda_qda_10', 'ela_meta.quad_simple.cond'}, Failed Levelset: 205
#
# Case: lhs_50
# Affected Keys: {'ela_level.lda_qda_25', 'ela_level.lda_qda_50', 'ela_level.lda_qda_10', 'ela_meta.quad_simple.cond'}, Failed Levelset: 0
#
# Case: lhs_75
# Affected Keys: {'ela_level.lda_qda_25', 'ela_level.lda_qda_50', 'ela_level.lda_qda_10', 'ela_meta.quad_simple.cond'}, Failed Levelset: 0
#
# Case: lhs_100
# Affected Keys: {'ela_level.lda_qda_25', 'ela_level.lda_qda_50', 'ela_level.lda_qda_10', 'ela_meta.quad_simple.cond'}, Failed Levelset: 0
#
# Case: sobol_25
# Affected Keys: {'disp.diff_median_02', 'disp.ratio_median_02', 'ela_level.lda_qda_50', 'ela_level.lda_qda_25', 'disp.ratio_mean_02', 'disp.diff_mean_02', 'ela_level.lda_qda_10', 'ela_meta.quad_simple.cond'}, Failed Levelset: 162
#
# Case: sobol_50
# Affected Keys: {'ela_level.lda_qda_25', 'ela_level.lda_qda_50', 'ela_level.lda_qda_10', 'ela_meta.quad_simple.cond'}, Failed Levelset: 0
#
# Case: sobol_75
# Affected Keys: {'ela_level.lda_qda_25', 'ela_level.lda_qda_50', 'ela_level.lda_qda_10', 'ela_meta.quad_simple.cond'}, Failed Levelset: 0
#
# Case: sobol_100
# Affected Keys: {'ela_level.lda_qda_25', 'ela_level.lda_qda_50', 'ela_level.lda_qda_10', 'ela_meta.quad_simple.cond'}, Failed Levelset: 0
#
# Case: uniform_25
# Affected Keys: {'disp.diff_median_02', 'disp.ratio_median_02', 'ela_level.lda_qda_50', 'ela_level.lda_qda_25', 'disp.ratio_mean_02', 'disp.diff_mean_02', 'ela_level.lda_qda_10', 'ela_meta.quad_simple.cond'}, Failed Levelset: 323
#
# Case: uniform_50
# Affected Keys: {'ela_level.lda_qda_25', 'ela_level.lda_qda_50', 'ela_level.lda_qda_10', 'ela_meta.quad_simple.cond'}, Failed Levelset: 0
#
# Case: uniform_75
# Affected Keys: {'ela_level.lda_qda_25', 'ela_level.lda_qda_50', 'ela_level.lda_qda_10', 'ela_meta.quad_simple.cond'}, Failed Levelset: 0
#
# Case: uniform_100
# Affected Keys: {'ela_level.lda_qda_25', 'ela_level.lda_qda_50', 'ela_level.lda_qda_10', 'ela_meta.quad_simple.cond'}, Failed Levelset: 0
#
# Overall Affected Keys: {'disp.diff_median_02', 'disp.ratio_median_02', 'ela_level.lda_qda_50', 'ela_level.lda_qda_25', 'ic.eps_ratio', 'disp.ratio_mean_02', 'disp.diff_mean_02', 'ela_level.lda_qda_10', 'ela_meta.quad_simple.cond'}

# %%
with open(data_dir / "ela_nan_inf_summary.pkl", "wb") as f:
    pickle.dump(nan_summary, f)

# %%
nan_summary['cma_random_25']
# Out:
# {'affected_keys': {'ela_level.lda_qda_10',
#   'ela_level.lda_qda_25',
#   'ela_meta.quad_simple.cond',
#   'ic.eps_ratio'},
#  'filtered': {'ela_level.lda_qda_10': {'nan': [],
#    'inf': [(5, 8, 2, 20),
#     (5, 23, 2, 23),
#     (5, 25, 2, 15),
#     (5, 31, 2, 15),
#     (5, 41, 2, 1),
#     (5, 42, 2, 18),
#     (5, 42, 2, 22),
#     (5, 44, 2, 1),
#     (5, 47, 2, 21),
#     (5, 54, 2, 7),
#     (5, 58, 2, 2),
#     (5, 63, 2, 18),
#     (5, 90, 2, 29),
#     (5, 95, 2, 25),
#     (5, 96, 2, 23),
#     (6, 3, 2, 20),
#     (7, 20, 2, 7),
#     (7, 44, 2, 21)]},
#   'ela_level.lda_qda_25': {'nan': [],
#    'inf': [(5, 5, 2, 23),
#     (5, 19, 2, 15),
#     (5, 41, 2, 25),
#     (5, 51, 2, 11),
#     (5, 53, 2, 20),
#     (5, 67, 2, 15),
#     (5, 78, 2, 23)]},
#   'ela_meta.quad_simple.cond': {'nan': [(5, 1, 2, 6),
#     (5, 1, 2, 10),
#     (5, 1, 2, 20),
#     (5, 2, 2, 13),
#     (5, 2, 2, 14),
#     (5, 4, 2, 26),
#     (5, 7, 2, 4),
#     (5, 8, 2, 8),
#     (5, 8, 2, 16),
#     (5, 8, 2, 27),
#     (5, 10, 2, 4),
#     (5, 11, 2, 21),
#     (5, 11, 2, 23),
#     (5, 12, 2, 13),
#     (5, 13, 2, 8),
#     (5, 13, 2, 20),
#     (5, 13, 2, 29),
#     (5, 15, 2, 3),
#     (5, 15, 2, 9),
#     (5, 15, 2, 26),
#     (5, 16, 2, 1),
#     (5, 18, 2, 4),
#     (5, 18, 2, 17),
#     (5, 18, 2, 22),
#     (5, 19, 2, 11),
#     (5, 19, 2, 12),
#     (5, 19, 2, 26),
#     (5, 20, 2, 12),
#     (5, 20, 2, 27),
#     (5, 21, 2, 10),
#     (5, 21, 2, 12),
#     (5, 22, 2, 11),
#     (5, 23, 2, 14),
#     (5, 23, 2, 15),
#     (5, 24, 2, 7),
#     (5, 24, 2, 14),
#     (5, 24, 2, 15),
#     (5, 25, 2, 5),
#     (5, 25, 2, 22),
#     (5, 25, 2, 26),
#     (5, 25, 2, 27),
#     (5, 25, 2, 29),
#     (5, 27, 2, 11),
#     (5, 28, 2, 6),
#     (5, 28, 2, 14),
#     (5, 28, 2, 20),
#     (5, 28, 2, 27),
#     (5, 29, 2, 4),
#     (5, 29, 2, 6),
#     (5, 29, 2, 16),
#     (5, 29, 2, 22),
#     (5, 30, 2, 6),
#     (5, 30, 2, 25),
#     (5, 31, 2, 2),
#     (5, 31, 2, 24),
#     (5, 31, 2, 27),
#     (5, 32, 2, 6),
#     (5, 32, 2, 19),
#     (5, 32, 2, 23),
#     (5, 34, 2, 11),
#     (5, 34, 2, 28),
#     (5, 36, 2, 11),
#     (5, 36, 2, 12),
#     (5, 36, 2, 20),
#     (5, 36, 2, 27),
#     (5, 37, 2, 16),
#     (5, 37, 2, 26),
#     (5, 38, 2, 9),
#     (5, 38, 2, 10),
#     (5, 39, 2, 13),
#     (5, 39, 2, 26),
#     (5, 40, 2, 15),
#     (5, 40, 2, 17),
#     (5, 40, 2, 18),
#     (5, 40, 2, 23),
#     (5, 42, 2, 7),
#     (5, 43, 2, 8),
#     (5, 43, 2, 19),
#     (5, 44, 2, 28),
#     (5, 45, 2, 4),
#     (5, 46, 2, 5),
#     (5, 46, 2, 17),
#     (5, 47, 2, 19),
#     (5, 51, 2, 15),
#     (5, 52, 2, 12),
#     (5, 53, 2, 0),
#     (5, 53, 2, 3),
#     (5, 54, 2, 27),
#     (5, 54, 2, 29),
#     (5, 56, 2, 3),
#     (5, 56, 2, 15),
#     (5, 56, 2, 17),
#     (5, 57, 2, 22),
#     (5, 58, 2, 10),
#     (5, 60, 2, 17),
#     (5, 61, 2, 4),
#     (5, 61, 2, 6),
#     (5, 61, 2, 18),
#     (5, 62, 2, 5),
#     (5, 34, 2, 18),
#     (5, 34, 2, 19),
#     (5, 34, 2, 20),
#     (5, 34, 2, 25),
#     (5, 34, 2, 29),
#     (5, 35, 2, 0),
#     (5, 35, 2, 5),
#     (5, 35, 2, 7),
#     (5, 35, 2, 15),
#     (5, 35, 2, 16),
#     (5, 35, 2, 17),
#     (5, 36, 2, 6),
#     (5, 36, 2, 7),
#     (5, 36, 2, 8),
#     (5, 36, 2, 10),
#     (5, 36, 2, 13),
#     (5, 36, 2, 14),
#     (5, 36, 2, 15),
#     (5, 36, 2, 19),
#     (5, 36, 2, 29),
#     (5, 37, 2, 0),
#     (5, 37, 2, 5),
#     (5, 37, 2, 8),
#     (5, 37, 2, 9),
#     (5, 37, 2, 10),
#     (5, 37, 2, 12),
#     (5, 37, 2, 13),
#     (5, 37, 2, 19),
#     (5, 37, 2, 21),
#     (5, 37, 2, 22),
#     (5, 37, 2, 24),
#     (5, 37, 2, 27),
#     (5, 38, 2, 2),
#     (5, 38, 2, 4),
#     (5, 38, 2, 6),
#     (5, 38, 2, 12),
#     (5, 38, 2, 15),
#     (5, 38, 2, 16),
#     (5, 38, 2, 17),
#     (5, 38, 2, 18),
#     (5, 38, 2, 19),
#     (5, 38, 2, 22),
#     (5, 38, 2, 24),
#     (5, 38, 2, 27),
#     (5, 38, 2, 28),
#     (5, 38, 2, 29),
#     (5, 39, 2, 1),
#     (5, 39, 2, 7),
#     (5, 39, 2, 10),
#     (5, 39, 2, 12),
#     (5, 39, 2, 15),
#     (5, 39, 2, 17),
#     (5, 39, 2, 19),
#     (5, 39, 2, 21),
#     (5, 39, 2, 22),
#     (5, 39, 2, 27),
#     (5, 39, 2, 28),
#     (5, 40, 2, 0),
#     (5, 40, 2, 2),
#     (5, 40, 2, 4),
#     (5, 40, 2, 10),
#     (5, 40, 2, 11),
#     (5, 40, 2, 13),
#     (5, 40, 2, 19),
#     (5, 40, 2, 21),
#     (5, 40, 2, 26),
#     (5, 40, 2, 28),
#     (5, 40, 2, 29),
#     (5, 41, 2, 0),
#     (5, 41, 2, 8),
#     (5, 41, 2, 10),
#     (5, 41, 2, 16),
#     (5, 41, 2, 23),
#     (5, 41, 2, 27),
#     (5, 41, 2, 28),
#     (5, 42, 2, 12),
#     (5, 42, 2, 14),
#     (5, 42, 2, 15),
#     (5, 42, 2, 17),
#     (5, 42, 2, 18),
#     (5, 42, 2, 19),
#     (5, 42, 2, 20),
#     (5, 42, 2, 21),
#     (5, 42, 2, 25),
#     (5, 43, 2, 3),
#     (5, 43, 2, 11),
#     (5, 43, 2, 13),
#     (5, 43, 2, 14),
#     (5, 43, 2, 22),
#     (5, 43, 2, 25),
#     (5, 43, 2, 28),
#     (5, 44, 2, 0),
#     (5, 44, 2, 1),
#     (5, 44, 2, 3),
#     (5, 44, 2, 7),
#     (5, 44, 2, 10),
#     (5, 44, 2, 12),
#     (5, 44, 2, 20),
#     (5, 44, 2, 26),
#     (5, 45, 2, 1),
#     (5, 45, 2, 2),
#     (5, 45, 2, 3),
#     (5, 45, 2, 6),
#     (5, 92, 2, 4),
#     (5, 92, 2, 7),
#     (5, 92, 2, 8),
#     (5, 92, 2, 9),
#     (5, 92, 2, 17),
#     (5, 92, 2, 18),
#     (5, 92, 2, 20),
#     (5, 92, 2, 25),
#     (5, 92, 2, 28),
#     (5, 93, 2, 7),
#     (5, 93, 2, 8),
#     (5, 93, 2, 11),
#     (5, 93, 2, 12),
#     (5, 93, 2, 16),
#     (5, 93, 2, 17),
#     (5, 93, 2, 18),
#     (5, 93, 2, 19),
#     (5, 93, 2, 20),
#     (5, 93, 2, 21),
#     (5, 93, 2, 22),
#     (5, 93, 2, 23),
#     (5, 93, 2, 25),
#     (5, 93, 2, 26),
#     (5, 93, 2, 27),
#     (5, 94, 2, 0),
#     ...]},
#   'ic.eps_ratio': {'nan': [],
#    'inf': [(7, 2, 2, 23),
#     (7, 23, 2, 22),
#     (7, 24, 2, 2),
#     (7, 30, 2, 19),
#     (7, 33, 2, 11),
#     (7, 49, 2, 19),
#     (7, 50, 2, 13),
#     (7, 50, 2, 29),
#     (7, 51, 2, 19),
#     (7, 70, 2, 12),
#     (7, 75, 2, 5),
#     (7, 75, 2, 15),
#     (7, 87, 2, 1)]}},
#  'failed_levelset': [(7, 1, 2, 1),
#   (7, 1, 2, 5),
#   (7, 1, 2, 6),
#   (7, 1, 2, 7),
#   (7, 1, 2, 8),
#   (7, 1, 2, 11),
#   (7, 1, 2, 15),
#   (7, 1, 2, 19),
#   (7, 1, 2, 23),
#   (7, 1, 2, 24),
#   (7, 2, 2, 4),
#   (7, 2, 2, 5),
#   (7, 2, 2, 20),
#   (7, 3, 2, 0),
#   (7, 3, 2, 1),
#   (7, 3, 2, 2),
#   (7, 3, 2, 4),
#   (7, 3, 2, 6),
#   (7, 3, 2, 7),
#   (7, 3, 2, 8),
#   (7, 3, 2, 9),
#   (7, 3, 2, 10),
#   (7, 3, 2, 12),
#   (7, 3, 2, 14),
#   (7, 3, 2, 17),
#   (7, 3, 2, 20),
#   (7, 3, 2, 22),
#   (7, 3, 2, 26),
#   (7, 3, 2, 28),
#   (7, 4, 2, 4),
#   (7, 4, 2, 5),
#   (7, 4, 2, 12),
#   (7, 4, 2, 15),
#   (7, 4, 2, 16),
#   (7, 4, 2, 18),
#   (7, 4, 2, 24),
#   (7, 5, 2, 0),
#   (7, 5, 2, 2),
#   (7, 5, 2, 9),
#   (7, 5, 2, 11),
#   (7, 5, 2, 12),
#   (7, 5, 2, 13),
#   (7, 5, 2, 14),
#   (7, 5, 2, 16),
#   (7, 5, 2, 17),
#   (7, 5, 2, 18),
#   (7, 5, 2, 19),
#   (7, 5, 2, 20),
#   (7, 5, 2, 21),
#   (7, 5, 2, 22),
#   (7, 5, 2, 24),
#   (7, 5, 2, 27),
#   (7, 5, 2, 28),
#   (7, 6, 2, 1),
#   (7, 6, 2, 4),
#   (7, 6, 2, 5),
#   (7, 6, 2, 6),
#   (7, 6, 2, 13),
#   (7, 6, 2, 14),
#   (7, 6, 2, 16),
#   (7, 6, 2, 18),
#   (7, 6, 2, 22),
#   (7, 6, 2, 28),
#   (7, 7, 2, 0),
#   (7, 7, 2, 2),
#   (7, 7, 2, 4),
#   (7, 7, 2, 5),
#   (7, 7, 2, 6),
#   (7, 7, 2, 8),
#   (7, 7, 2, 16),
#   (7, 7, 2, 19),
#   (7, 7, 2, 27),
#   (7, 7, 2, 29),
#   (7, 8, 2, 0),
#   (7, 8, 2, 1),
#   (7, 8, 2, 3),
#   (7, 8, 2, 5),
#   (7, 8, 2, 8),
#   (7, 8, 2, 17),
#   (7, 8, 2, 18),
#   (7, 8, 2, 20),
#   (7, 8, 2, 21),
#   (7, 8, 2, 23),
#   (7, 8, 2, 25),
#   (7, 8, 2, 26),
#   (7, 8, 2, 28),
#   (7, 8, 2, 29),
#   (7, 9, 2, 0),
#   (7, 9, 2, 1),
#   (7, 9, 2, 2),
#   (7, 9, 2, 5),
#   (7, 9, 2, 6),
#   (7, 9, 2, 13),
#   (7, 9, 2, 14),
#   (7, 9, 2, 20),
#   (7, 9, 2, 25),
#   (7, 9, 2, 26),
#   (7, 9, 2, 29),
#   (7, 10, 2, 1),
#   (7, 10, 2, 13),
#   (7, 10, 2, 21),
#   (7, 11, 2, 5),
#   (7, 11, 2, 7),
#   (7, 11, 2, 11),
#   (7, 11, 2, 16),
#   (7, 11, 2, 18),
#   (7, 11, 2, 22),
#   (7, 11, 2, 23),
#   (7, 11, 2, 25),
#   (7, 11, 2, 26),
#   (7, 11, 2, 28),
#   (7, 12, 2, 0),
#   (7, 12, 2, 1),
#   (7, 12, 2, 12),
#   (7, 12, 2, 15),
#   (7, 12, 2, 18),
#   (7, 12, 2, 19),
#   (7, 12, 2, 22),
#   (7, 12, 2, 25),
#   (7, 12, 2, 27),
#   (7, 13, 2, 0),
#   (7, 13, 2, 2),
#   (7, 13, 2, 3),
#   (7, 13, 2, 6),
#   (7, 13, 2, 11),
#   (7, 13, 2, 12),
#   (7, 13, 2, 13),
#   (7, 13, 2, 18),
#   (7, 13, 2, 19),
#   (7, 13, 2, 20),
#   (7, 13, 2, 21),
#   (7, 13, 2, 23),
#   (7, 13, 2, 27),
#   (7, 14, 2, 0),
#   (7, 14, 2, 7),
#   (7, 14, 2, 10),
#   (7, 14, 2, 13),
#   (7, 14, 2, 17),
#   (7, 14, 2, 18),
#   (7, 14, 2, 20),
#   (7, 14, 2, 21),
#   (7, 14, 2, 24),
#   (7, 14, 2, 25),
#   (7, 14, 2, 29),
#   (7, 15, 2, 1),
#   (7, 15, 2, 2),
#   (7, 15, 2, 5),
#   (7, 15, 2, 7),
#   (7, 15, 2, 10),
#   (7, 15, 2, 11),
#   (7, 15, 2, 12),
#   (7, 15, 2, 14),
#   (7, 15, 2, 17),
#   (7, 15, 2, 18),
#   (7, 15, 2, 19),
#   (7, 15, 2, 22),
#   (7, 15, 2, 24),
#   (7, 15, 2, 27),
#   (7, 15, 2, 29),
#   (7, 16, 2, 1),
#   (7, 16, 2, 18),
#   (7, 16, 2, 26),
#   (7, 16, 2, 27),
#   (7, 17, 2, 4),
#   (7, 17, 2, 7),
#   (7, 17, 2, 15),
#   (7, 17, 2, 16),
#   (7, 17, 2, 17),
#   (7, 17, 2, 18),
#   (7, 17, 2, 20),
#   (7, 17, 2, 23),
#   (7, 18, 2, 0),
#   (7, 18, 2, 2),
#   (7, 18, 2, 3),
#   (7, 18, 2, 7),
#   (7, 18, 2, 8),
#   (7, 18, 2, 12),
#   (7, 18, 2, 16),
#   (7, 18, 2, 17),
#   (7, 18, 2, 20),
#   (7, 18, 2, 23),
#   (7, 18, 2, 26),
#   (7, 18, 2, 27),
#   (7, 18, 2, 28),
#   (7, 19, 2, 0),
#   (7, 19, 2, 3),
#   (7, 19, 2, 4),
#   (7, 19, 2, 6),
#   (7, 19, 2, 7),
#   (7, 19, 2, 14),
#   (7, 19, 2, 15),
#   (7, 19, 2, 16),
#   (7, 19, 2, 21),
#   (7, 19, 2, 23),
#   (7, 19, 2, 24),
#   (7, 20, 2, 5),
#   (7, 20, 2, 6),
#   (7, 20, 2, 8),
#   (7, 20, 2, 9),
#   (7, 20, 2, 13),
#   (7, 20, 2, 14),
#   (7, 20, 2, 16),
#   (7, 20, 2, 22),
#   (7, 20, 2, 25),
#   (7, 21, 2, 3),
#   (7, 21, 2, 5),
#   (7, 21, 2, 6),
#   (7, 21, 2, 8),
#   (7, 21, 2, 9),
#   (7, 21, 2, 11),
#   (7, 21, 2, 12),
#   (7, 21, 2, 14),
#   (7, 21, 2, 19),
#   (7, 21, 2, 20),
#   (7, 21, 2, 22),
#   (7, 21, 2, 23),
#   (7, 21, 2, 26),
#   (7, 21, 2, 29),
#   (7, 22, 2, 4),
#   (7, 22, 2, 5),
#   (7, 22, 2, 7),
#   (7, 22, 2, 11),
#   (7, 22, 2, 14),
#   (7, 22, 2, 16),
#   (7, 22, 2, 22),
#   (7, 22, 2, 26),
#   (7, 22, 2, 27),
#   (7, 24, 2, 3),
#   (7, 25, 2, 0),
#   (7, 25, 2, 1),
#   (7, 25, 2, 2),
#   (7, 25, 2, 4),
#   (7, 25, 2, 5),
#   (7, 25, 2, 6),
#   (7, 25, 2, 7),
#   (7, 25, 2, 8),
#   (7, 25, 2, 9),
#   (7, 25, 2, 13),
#   (7, 25, 2, 19),
#   (7, 25, 2, 20),
#   (7, 25, 2, 23),
#   (7, 25, 2, 24),
#   (7, 25, 2, 25),
#   (7, 25, 2, 28),
#   (7, 26, 2, 0),
#   (7, 26, 2, 8),
#   (7, 26, 2, 10),
#   (7, 26, 2, 13),
#   (7, 26, 2, 20),
#   (7, 26, 2, 26),
#   (7, 26, 2, 27),
#   (7, 26, 2, 28),
#   (7, 26, 2, 29),
#   (7, 27, 2, 20),
#   (7, 27, 2, 24),
#   (7, 28, 2, 12),
#   (7, 29, 2, 0),
#   (7, 29, 2, 2),
#   (7, 29, 2, 7),
#   (7, 29, 2, 13),
#   (7, 29, 2, 15),
#   (7, 29, 2, 16),
#   (7, 29, 2, 17),
#   (7, 29, 2, 20),
#   (7, 29, 2, 23),
#   (7, 29, 2, 25),
#   (7, 29, 2, 26),
#   (7, 29, 2, 29),
#   (7, 30, 2, 10),
#   (7, 30, 2, 29),
#   (7, 31, 2, 0),
#   (7, 31, 2, 7),
#   (7, 31, 2, 19),
#   (7, 31, 2, 20),
#   (7, 31, 2, 24),
#   (7, 31, 2, 27),
#   (7, 32, 2, 1),
#   (7, 32, 2, 5),
#   (7, 32, 2, 12),
#   (7, 32, 2, 16),
#   (7, 32, 2, 17),
#   (7, 32, 2, 21),
#   (7, 32, 2, 29),
#   (7, 34, 2, 4),
#   (7, 34, 2, 5),
#   (7, 34, 2, 7),
#   (7, 34, 2, 8),
#   (7, 34, 2, 9),
#   (7, 34, 2, 10),
#   (7, 34, 2, 15),
#   (7, 34, 2, 25),
#   (7, 34, 2, 27),
#   (7, 35, 2, 1),
#   (7, 35, 2, 3),
#   (7, 35, 2, 5),
#   (7, 35, 2, 22),
#   (7, 35, 2, 23),
#   (7, 37, 2, 1),
#   (7, 37, 2, 2),
#   (7, 37, 2, 3),
#   (7, 37, 2, 4),
#   (7, 37, 2, 10),
#   (7, 37, 2, 12),
#   (7, 37, 2, 14),
#   (7, 37, 2, 16),
#   (7, 37, 2, 17),
#   (7, 37, 2, 23),
#   (7, 37, 2, 24),
#   (7, 37, 2, 25),
#   (7, 37, 2, 26),
#   (7, 38, 2, 5),
#   (7, 38, 2, 9),
#   (7, 38, 2, 11),
#   (7, 38, 2, 12),
#   (7, 38, 2, 28),
#   (7, 39, 2, 1),
#   (7, 39, 2, 3),
#   (7, 39, 2, 4),
#   (7, 39, 2, 6),
#   (7, 39, 2, 7),
#   (7, 39, 2, 8),
#   (7, 39, 2, 10),
#   (7, 39, 2, 12),
#   (7, 39, 2, 13),
#   (7, 39, 2, 14),
#   (7, 39, 2, 15),
#   (7, 39, 2, 16),
#   (7, 39, 2, 18),
#   (7, 39, 2, 20),
#   (7, 39, 2, 22),
#   (7, 39, 2, 25),
#   (7, 39, 2, 29),
#   (7, 40, 2, 3),
#   (7, 40, 2, 6),
#   (7, 40, 2, 14),
#   (7, 40, 2, 15),
#   (7, 40, 2, 16),
#   (7, 40, 2, 23),
#   (7, 40, 2, 24),
#   (7, 40, 2, 28),
#   (7, 40, 2, 29),
#   (7, 41, 2, 17),
#   (7, 42, 2, 0),
#   (7, 42, 2, 2),
#   (7, 42, 2, 3),
#   (7, 42, 2, 9),
#   (7, 42, 2, 14),
#   (7, 42, 2, 15),
#   (7, 42, 2, 21),
#   (7, 42, 2, 23),
#   (7, 42, 2, 24),
#   (7, 42, 2, 27),
#   (7, 42, 2, 29),
#   (7, 43, 2, 0),
#   (7, 43, 2, 1),
#   (7, 43, 2, 5),
#   (7, 43, 2, 8),
#   (7, 43, 2, 9),
#   (7, 43, 2, 10),
#   (7, 43, 2, 11),
#   (7, 43, 2, 12),
#   (7, 43, 2, 13),
#   (7, 43, 2, 14),
#   (7, 43, 2, 15),
#   (7, 43, 2, 16),
#   (7, 43, 2, 19),
#   (7, 43, 2, 24),
#   (7, 43, 2, 26),
#   (7, 44, 2, 0),
#   (7, 44, 2, 1),
#   (7, 44, 2, 2),
#   (7, 44, 2, 3),
#   (7, 44, 2, 4),
#   (7, 44, 2, 5),
#   (7, 44, 2, 8),
#   (7, 44, 2, 9),
#   (7, 44, 2, 12),
#   (7, 44, 2, 13),
#   (7, 44, 2, 14),
#   (7, 44, 2, 15),
#   (7, 44, 2, 16),
#   (7, 44, 2, 17),
#   (7, 44, 2, 19),
#   (7, 44, 2, 20),
#   (7, 44, 2, 22),
#   (7, 44, 2, 23),
#   (7, 44, 2, 24),
#   (7, 44, 2, 26),
#   (7, 44, 2, 29),
#   (7, 45, 2, 2),
#   (7, 45, 2, 4),
#   (7, 45, 2, 14),
#   (7, 45, 2, 15),
#   (7, 45, 2, 19),
#   (7, 45, 2, 26),
#   (7, 45, 2, 28),
#   (7, 45, 2, 29),
#   (7, 46, 2, 0),
#   (7, 46, 2, 1),
#   (7, 46, 2, 2),
#   (7, 46, 2, 5),
#   (7, 46, 2, 8),
#   (7, 46, 2, 10),
#   (7, 46, 2, 11),
#   (7, 46, 2, 13),
#   (7, 46, 2, 15),
#   (7, 46, 2, 22),
#   (7, 46, 2, 23),
#   (7, 46, 2, 24),
#   (7, 46, 2, 25),
#   (7, 47, 2, 1),
#   (7, 47, 2, 4),
#   (7, 47, 2, 8),
#   (7, 47, 2, 13),
#   (7, 47, 2, 19),
#   (7, 47, 2, 21),
#   (7, 47, 2, 22),
#   (7, 47, 2, 25),
#   (7, 47, 2, 26),
#   (7, 47, 2, 28),
#   (7, 47, 2, 29),
#   (7, 48, 2, 4),
#   (7, 48, 2, 5),
#   (7, 48, 2, 8),
#   (7, 48, 2, 12),
#   (7, 48, 2, 15),
#   (7, 48, 2, 16),
#   (7, 48, 2, 17),
#   (7, 48, 2, 18),
#   (7, 48, 2, 20),
#   (7, 48, 2, 21),
#   (7, 48, 2, 22),
#   (7, 48, 2, 23),
#   (7, 48, 2, 27),
#   (7, 49, 2, 0),
#   (7, 49, 2, 1),
#   (7, 49, 2, 4),
#   (7, 49, 2, 7),
#   (7, 49, 2, 8),
#   (7, 49, 2, 10),
#   (7, 49, 2, 11),
#   (7, 49, 2, 12),
#   (7, 49, 2, 13),
#   (7, 49, 2, 15),
#   (7, 49, 2, 17),
#   (7, 49, 2, 23),
#   (7, 49, 2, 24),
#   (7, 49, 2, 25),
#   (7, 49, 2, 28),
#   (7, 49, 2, 29),
#   (7, 50, 2, 1),
#   (7, 50, 2, 7),
#   (7, 50, 2, 9),
#   (7, 50, 2, 15),
#   (7, 50, 2, 20),
#   (7, 51, 2, 0),
#   (7, 51, 2, 1),
#   (7, 51, 2, 14),
#   (7, 51, 2, 26),
#   (7, 52, 2, 1),
#   (7, 52, 2, 3),
#   (7, 52, 2, 4),
#   (7, 52, 2, 15),
#   (7, 52, 2, 19),
#   (7, 52, 2, 20),
#   (7, 52, 2, 22),
#   (7, 52, 2, 25),
#   (7, 52, 2, 26),
#   (7, 52, 2, 27),
#   (7, 52, 2, 29),
#   (7, 53, 2, 0),
#   (7, 53, 2, 1),
#   (7, 53, 2, 3),
#   (7, 53, 2, 4),
#   (7, 53, 2, 13),
#   (7, 53, 2, 14),
#   (7, 53, 2, 16),
#   (7, 53, 2, 20),
#   (7, 53, 2, 23),
#   (7, 53, 2, 29),
#   (7, 54, 2, 2),
#   (7, 54, 2, 3),
#   (7, 54, 2, 6),
#   (7, 54, 2, 7),
#   (7, 54, 2, 9),
#   (7, 54, 2, 10),
#   (7, 54, 2, 13),
#   (7, 54, 2, 14),
#   (7, 54, 2, 18),
#   (7, 54, 2, 29),
#   (7, 55, 2, 0),
#   (7, 55, 2, 1),
#   (7, 55, 2, 4),
#   (7, 55, 2, 8),
#   (7, 55, 2, 11),
#   (7, 55, 2, 14),
#   (7, 55, 2, 17),
#   (7, 55, 2, 18),
#   (7, 55, 2, 19),
#   (7, 55, 2, 20),
#   (7, 55, 2, 25),
#   (7, 55, 2, 27),
#   (7, 55, 2, 28),
#   (7, 56, 2, 3),
#   (7, 56, 2, 7),
#   (7, 56, 2, 10),
#   (7, 56, 2, 12),
#   (7, 56, 2, 13),
#   (7, 56, 2, 17),
#   (7, 56, 2, 18),
#   (7, 56, 2, 19),
#   (7, 56, 2, 21),
#   (7, 56, 2, 22),
#   (7, 56, 2, 26),
#   (7, 56, 2, 27),
#   (7, 57, 2, 1),
#   (7, 57, 2, 2),
#   (7, 57, 2, 8),
#   (7, 57, 2, 9),
#   (7, 57, 2, 12),
#   (7, 57, 2, 14),
#   (7, 57, 2, 19),
#   (7, 57, 2, 23),
#   (7, 57, 2, 25),
#   (7, 57, 2, 26),
#   (7, 57, 2, 27),
#   (7, 58, 2, 0),
#   (7, 58, 2, 1),
#   (7, 58, 2, 2),
#   (7, 58, 2, 5),
#   (7, 58, 2, 6),
#   (7, 58, 2, 9),
#   (7, 58, 2, 12),
#   (7, 58, 2, 14),
#   (7, 58, 2, 16),
#   (7, 58, 2, 18),
#   (7, 58, 2, 21),
#   (7, 58, 2, 22),
#   (7, 58, 2, 26),
#   (7, 58, 2, 27),
#   (7, 58, 2, 28),
#   (7, 58, 2, 29),
#   (7, 59, 2, 1),
#   (7, 59, 2, 2),
#   (7, 59, 2, 3),
#   (7, 59, 2, 8),
#   (7, 59, 2, 15),
#   (7, 59, 2, 18),
#   (7, 59, 2, 19),
#   (7, 59, 2, 20),
#   (7, 59, 2, 21),
#   (7, 59, 2, 22),
#   (7, 59, 2, 23),
#   (7, 59, 2, 25),
#   (7, 59, 2, 27),
#   (7, 59, 2, 28),
#   (7, 60, 2, 0),
#   (7, 60, 2, 1),
#   (7, 60, 2, 2),
#   (7, 60, 2, 3),
#   (7, 60, 2, 5),
#   (7, 60, 2, 6),
#   (7, 60, 2, 7),
#   (7, 60, 2, 8),
#   (7, 60, 2, 10),
#   (7, 60, 2, 12),
#   (7, 60, 2, 13),
#   (7, 60, 2, 16),
#   (7, 60, 2, 17),
#   (7, 60, 2, 18),
#   (7, 60, 2, 19),
#   (7, 60, 2, 20),
#   (7, 60, 2, 21),
#   (7, 60, 2, 23),
#   (7, 60, 2, 24),
#   (7, 60, 2, 25),
#   (7, 60, 2, 26),
#   (7, 60, 2, 29),
#   (7, 61, 2, 0),
#   (7, 61, 2, 1),
#   (7, 61, 2, 4),
#   (7, 61, 2, 5),
#   (7, 61, 2, 7),
#   (7, 61, 2, 8),
#   (7, 61, 2, 10),
#   (7, 61, 2, 11),
#   (7, 61, 2, 16),
#   (7, 61, 2, 17),
#   (7, 61, 2, 18),
#   (7, 61, 2, 21),
#   (7, 61, 2, 24),
#   (7, 61, 2, 25),
#   (7, 61, 2, 26),
#   (7, 61, 2, 27),
#   (7, 61, 2, 28),
#   (7, 61, 2, 29),
#   (7, 62, 2, 0),
#   (7, 62, 2, 10),
#   (7, 62, 2, 12),
#   (7, 62, 2, 14),
#   (7, 62, 2, 17),
#   (7, 62, 2, 18),
#   (7, 63, 2, 0),
#   (7, 63, 2, 5),
#   (7, 63, 2, 6),
#   (7, 63, 2, 9),
#   (7, 63, 2, 13),
#   (7, 63, 2, 14),
#   (7, 63, 2, 16),
#   (7, 63, 2, 21),
#   (7, 63, 2, 24),
#   (7, 63, 2, 28),
#   (7, 63, 2, 29),
#   (7, 64, 2, 1),
#   (7, 64, 2, 2),
#   (7, 64, 2, 4),
#   (7, 64, 2, 7),
#   (7, 64, 2, 8),
#   (7, 64, 2, 9),
#   (7, 64, 2, 10),
#   (7, 64, 2, 11),
#   (7, 64, 2, 14),
#   (7, 64, 2, 15),
#   (7, 64, 2, 20),
#   (7, 64, 2, 21),
#   (7, 64, 2, 22),
#   (7, 64, 2, 24),
#   (7, 64, 2, 25),
#   (7, 64, 2, 26),
#   (7, 64, 2, 27),
#   (7, 64, 2, 29),
#   (7, 65, 2, 0),
#   (7, 65, 2, 4),
#   (7, 65, 2, 5),
#   (7, 65, 2, 7),
#   (7, 65, 2, 11),
#   (7, 65, 2, 12),
#   (7, 65, 2, 13),
#   (7, 65, 2, 16),
#   (7, 65, 2, 20),
#   (7, 65, 2, 21),
#   (7, 65, 2, 22),
#   (7, 66, 2, 3),
#   (7, 66, 2, 4),
#   (7, 66, 2, 6),
#   (7, 66, 2, 9),
#   (7, 66, 2, 12),
#   (7, 66, 2, 19),
#   (7, 66, 2, 20),
#   (7, 66, 2, 21),
#   (7, 66, 2, 28),
#   (7, 67, 2, 0),
#   (7, 67, 2, 9),
#   (7, 67, 2, 12),
#   (7, 67, 2, 20),
#   (7, 67, 2, 23),
#   (7, 67, 2, 27),
#   (7, 68, 2, 0),
#   (7, 68, 2, 1),
#   (7, 68, 2, 3),
#   (7, 68, 2, 4),
#   (7, 68, 2, 7),
#   (7, 68, 2, 8),
#   (7, 68, 2, 13),
#   (7, 68, 2, 17),
#   (7, 68, 2, 20),
#   (7, 68, 2, 26),
#   (7, 68, 2, 27),
#   (7, 68, 2, 29),
#   (7, 69, 2, 0),
#   (7, 69, 2, 1),
#   (7, 69, 2, 2),
#   (7, 69, 2, 4),
#   (7, 69, 2, 9),
#   (7, 69, 2, 11),
#   (7, 69, 2, 12),
#   (7, 69, 2, 18),
#   (7, 69, 2, 20),
#   (7, 69, 2, 22),
#   (7, 69, 2, 23),
#   (7, 69, 2, 24),
#   (7, 69, 2, 26),
#   (7, 69, 2, 28),
#   (7, 70, 2, 25),
#   (7, 71, 2, 0),
#   (7, 71, 2, 2),
#   (7, 71, 2, 4),
#   (7, 71, 2, 7),
#   (7, 71, 2, 9),
#   (7, 71, 2, 11),
#   (7, 71, 2, 13),
#   (7, 71, 2, 18),
#   (7, 71, 2, 23),
#   (7, 71, 2, 25),
#   (7, 71, 2, 26),
#   (7, 71, 2, 28),
#   (7, 71, 2, 29),
#   (7, 72, 2, 23),
#   (7, 73, 2, 0),
#   (7, 73, 2, 4),
#   (7, 73, 2, 9),
#   (7, 73, 2, 17),
#   (7, 73, 2, 23),
#   (7, 73, 2, 28),
#   (7, 74, 2, 1),
#   (7, 74, 2, 2),
#   (7, 74, 2, 4),
#   (7, 74, 2, 6),
#   (7, 74, 2, 8),
#   (7, 74, 2, 10),
#   (7, 74, 2, 11),
#   (7, 74, 2, 12),
#   (7, 74, 2, 13),
#   (7, 74, 2, 15),
#   (7, 74, 2, 16),
#   (7, 74, 2, 24),
#   (7, 74, 2, 29),
#   (7, 75, 2, 1),
#   (7, 75, 2, 3),
#   (7, 75, 2, 7),
#   (7, 75, 2, 11),
#   (7, 75, 2, 17),
#   (7, 75, 2, 22),
#   (7, 75, 2, 28),
#   (7, 76, 2, 25),
#   (7, 76, 2, 28),
#   (7, 77, 2, 0),
#   (7, 77, 2, 2),
#   (7, 77, 2, 5),
#   (7, 77, 2, 11),
#   (7, 77, 2, 16),
#   (7, 77, 2, 18),
#   (7, 77, 2, 19),
#   (7, 77, 2, 22),
#   (7, 77, 2, 23),
#   (7, 77, 2, 25),
#   (7, 77, 2, 28),
#   (7, 78, 2, 1),
#   (7, 78, 2, 2),
#   (7, 78, 2, 7),
#   (7, 78, 2, 10),
#   (7, 78, 2, 11),
#   (7, 78, 2, 14),
#   (7, 78, 2, 15),
#   (7, 78, 2, 18),
#   (7, 78, 2, 20),
#   (7, 78, 2, 23),
#   (7, 78, 2, 26),
#   (7, 78, 2, 27),
#   (7, 79, 2, 1),
#   (7, 79, 2, 2),
#   (7, 79, 2, 4),
#   (7, 79, 2, 8),
#   (7, 79, 2, 10),
#   (7, 79, 2, 12),
#   (7, 79, 2, 24),
#   (7, 80, 2, 1),
#   (7, 80, 2, 7),
#   (7, 80, 2, 8),
#   (7, 80, 2, 11),
#   (7, 80, 2, 13),
#   (7, 80, 2, 15),
#   (7, 80, 2, 17),
#   (7, 80, 2, 19),
#   (7, 80, 2, 21),
#   (7, 80, 2, 23),
#   (7, 80, 2, 24),
#   (7, 80, 2, 25),
#   (7, 80, 2, 28),
#   (7, 81, 2, 3),
#   (7, 81, 2, 17),
#   (7, 81, 2, 22),
#   (7, 81, 2, 23),
#   (7, 81, 2, 29),
#   (7, 82, 2, 0),
#   (7, 82, 2, 4),
#   (7, 82, 2, 5),
#   (7, 82, 2, 6),
#   (7, 82, 2, 8),
#   (7, 82, 2, 9),
#   (7, 82, 2, 10),
#   (7, 82, 2, 11),
#   (7, 82, 2, 19),
#   (7, 82, 2, 21),
#   (7, 82, 2, 22),
#   (7, 82, 2, 23),
#   (7, 82, 2, 26),
#   (7, 82, 2, 27),
#   (7, 83, 2, 4),
#   (7, 83, 2, 6),
#   (7, 83, 2, 11),
#   (7, 83, 2, 12),
#   (7, 83, 2, 15),
#   (7, 83, 2, 16),
#   (7, 83, 2, 18),
#   (7, 83, 2, 22),
#   (7, 83, 2, 23),
#   (7, 83, 2, 27),
#   (7, 83, 2, 29),
#   (7, 84, 2, 6),
#   (7, 84, 2, 10),
#   (7, 84, 2, 12),
#   (7, 84, 2, 13),
#   (7, 84, 2, 14),
#   (7, 84, 2, 17),
#   (7, 84, 2, 19),
#   (7, 84, 2, 21),
#   (7, 84, 2, 22),
#   (7, 85, 2, 10),
#   (7, 85, 2, 11),
#   (7, 85, 2, 14),
#   (7, 85, 2, 20),
#   (7, 85, 2, 21),
#   (7, 85, 2, 28),
#   (7, 86, 2, 1),
#   (7, 86, 2, 2),
#   (7, 86, 2, 6),
#   (7, 86, 2, 8),
#   (7, 86, 2, 10),
#   (7, 86, 2, 11),
#   (7, 86, 2, 13),
#   (7, 86, 2, 17),
#   (7, 86, 2, 18),
#   (7, 86, 2, 19),
#   (7, 86, 2, 22),
#   (7, 86, 2, 23),
#   (7, 86, 2, 28),
#   (7, 86, 2, 29),
#   (7, 87, 2, 22),
#   (7, 87, 2, 28),
#   (7, 88, 2, 1),
#   (7, 88, 2, 2),
#   (7, 88, 2, 4),
#   (7, 88, 2, 5),
#   (7, 88, 2, 7),
#   (7, 88, 2, 11),
#   (7, 88, 2, 13),
#   (7, 88, 2, 14),
#   (7, 88, 2, 15),
#   (7, 88, 2, 16),
#   (7, 88, 2, 18),
#   (7, 88, 2, 25),
#   (7, 88, 2, 26),
#   (7, 88, 2, 28),
#   (7, 88, 2, 29),
#   (7, 89, 2, 0),
#   (7, 89, 2, 2),
#   (7, 89, 2, 15),
#   (7, 89, 2, 18),
#   (7, 89, 2, 19),
#   (7, 89, 2, 22),
#   (7, 89, 2, 23),
#   (7, 89, 2, 26),
#   (7, 90, 2, 4),
#   (7, 90, 2, 5),
#   (7, 90, 2, 9),
#   (7, 90, 2, 10),
#   (7, 90, 2, 15),
#   (7, 90, 2, 16),
#   (7, 90, 2, 17),
#   (7, 90, 2, 20),
#   (7, 90, 2, 21),
#   (7, 90, 2, 23),
#   (7, 90, 2, 27),
#   (7, 90, 2, 28),
#   (7, 90, 2, 29),
#   (7, 91, 2, 2),
#   (7, 91, 2, 4),
#   (7, 91, 2, 6),
#   (7, 91, 2, 8),
#   (7, 91, 2, 9),
#   (7, 91, 2, 13),
#   (7, 91, 2, 15),
#   (7, 91, 2, 16),
#   (7, 91, 2, 17),
#   (7, 91, 2, 19),
#   (7, 91, 2, 22),
#   (7, 91, 2, 24),
#   (7, 91, 2, 29),
#   (7, 92, 2, 2),
#   (7, 92, 2, 3),
#   (7, 92, 2, 5),
#   (7, 92, 2, 15),
#   (7, 92, 2, 16),
#   (7, 92, 2, 18),
#   (7, 92, 2, 22),
#   (7, 92, 2, 25),
#   (7, 93, 2, 0),
#   (7, 93, 2, 3),
#   (7, 93, 2, 4),
#   (7, 93, 2, 8),
#   (7, 93, 2, 10),
#   (7, 93, 2, 11),
#   (7, 93, 2, 16),
#   (7, 93, 2, 17),
#   (7, 93, 2, 18),
#   (7, 93, 2, 19),
#   (7, 93, 2, 20),
#   (7, 93, 2, 22),
#   (7, 93, 2, 28),
#   (7, 94, 2, 0),
#   (7, 94, 2, 1),
#   (7, 94, 2, 5),
#   (7, 94, 2, 8),
#   (7, 94, 2, 9),
#   (7, 94, 2, 10),
#   (7, 94, 2, 11),
#   (7, 94, 2, 15),
#   (7, 94, 2, 21),
#   (7, 94, 2, 23),
#   (7, 94, 2, 24),
#   (7, 94, 2, 25),
#   (7, 94, 2, 26),
#   (7, 94, 2, 27),
#   (7, 94, 2, 29),
#   (7, 95, 2, 3),
#   (7, 95, 2, 7),
#   (7, 95, 2, 8),
#   (7, 95, 2, 10),
#   (7, 95, 2, 15),
#   (7, 95, 2, 20),
#   (7, 95, 2, 26),
#   (7, 95, 2, 27),
#   (7, 96, 2, 11),
#   (7, 96, 2, 15),
#   (7, 96, 2, 16),
#   (7, 96, 2, 23),
#   (7, 96, 2, 27),
#   (7, 97, 2, 2),
#   (7, 97, 2, 12),
#   (7, 97, 2, 17),
#   (7, 97, 2, 19),
#   (7, 97, 2, 20),
#   (7, 97, 2, 21),
#   (7, 97, 2, 29),
#   (7, 98, 2, 0),
#   (7, 98, 2, 2),
#   (7, 98, 2, 3),
#   (7, 98, 2, 5),
#   (7, 98, 2, 6),
#   (7, 98, 2, 8),
#   (7, 98, 2, 9),
#   (7, 98, 2, 10),
#   (7, 98, 2, 18),
#   (7, 98, 2, 20),
#   (7, 98, 2, 21),
#   (7, 98, 2, 24),
#   (7, 98, 2, 25),
#   (7, 98, 2, 29),
#   (7, 99, 2, 1),
#   (7, 99, 2, 3),
#   (7, 99, 2, 4),
#   (7, 99, 2, 5),
#   (7, 99, 2, 9),
#   (7, 99, 2, 16),
#   (7, 99, 2, 18),
#   (7, 99, 2, 19),
#   (7, 99, 2, 20),
#   (7, 99, 2, 23),
#   (7, 99, 2, 25),
#   (7, 99, 2, 26),
#   (7, 99, 2, 27),
#   (7, 99, 2, 28),
#   (7, 100, 2, 1),
#   (7, 100, 2, 2),
#   (7, 100, 2, 3),
#   (7, 100, 2, 5),
#   (7, 100, 2, 6),
#   (7, 100, 2, 9),
#   (7, 100, 2, 11),
#   (7, 100, 2, 12),
#   (7, 100, 2, 14),
#   (7, 100, 2, 15),
#   (7, 100, 2, 17),
#   (7, 100, 2, 18),
#   (7, 100, 2, 22),
#   (7, 100, 2, 23),
#   (7, 100, 2, 26),
#   (7, 100, 2, 27),
#   (7, 100, 2, 29),
#   (21, 76, 2, 2)]}
