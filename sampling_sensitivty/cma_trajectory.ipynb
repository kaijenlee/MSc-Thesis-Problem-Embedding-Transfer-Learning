# %%
import cocoex

# %%
problem = cocoex.BareProblem(
  suite_name="bbob",
  function=1,
  dimension=2,
  instance=1
)

# %%
problem.best_value()
# Out:
# 79.48

# %%
problem.best_parameter()
# Out:
# array([ 0.2528, -1.1568])
