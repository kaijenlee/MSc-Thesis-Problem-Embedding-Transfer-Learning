# %%
from ela_fixed_n import *
from pathlib import Path

# %%
h5_dir = Path("/Users/leekaijen/t7ssd/dim2feat/rf")
n_to_h5 = {
        6:  h5_dir / "ela_learning_N6.h5",
        12:  h5_dir / "ela_learning_N12.h5",
        24:  h5_dir /"ela_learning_N24.h5",
        60:  h5_dir / "ela_learning_N60.h5",
}

# %%
plt, ax = plot_fixed_n_bars(
    n_to_h5,
    sampler="cma_random",
    ylim_median=(0.6, 0.95),
    ylim_allruns=(0.5, 0.95),
    show=True,
)

plt, ax = plot_fixed_n_bars(
    n_to_h5,
    sampler="uniform",
    ylim_median=(0.6, 0.95),
    ylim_allruns=(0.6, 0.95),
    show=True,
)

plt, ax = plot_fixed_n_bars(
    n_to_h5,
    sampler="lhs",
    ylim_median=(0.6, 0.95),
    ylim_allruns=(0.6, 0.95),
    show=True,
)

plt, ax = plot_fixed_n_bars(
    n_to_h5,
    sampler="ilhs",
    ylim_median=(0.6, 0.95),
    ylim_allruns=(0.6, 0.95),
    show=True,
)

plt, ax = plot_fixed_n_bars(
    n_to_h5,
    sampler="sobol",
    ylim_median=(0.6, 0.95),
    ylim_allruns=(0.6, 0.95),
    show=True,
)
