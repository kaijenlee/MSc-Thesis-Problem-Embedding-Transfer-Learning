# %%
from sampling_sensitivty.plots.stability.cv.cv_plot_helpers import *
import warnings
from pathlib import Path

from sampling_sensitivty.plots.stability.cv.cv_plot_helpers import load_cv_data

warnings.filterwarnings("ignore")
ela_cv = load_cv_data(Path("/Users/leekaijen/t7ssd/dim2feat/cv/ela_cv_results.pkl"))
tla_cv = load_cv_data(Path("/Users/leekaijen/t7ssd/dim2feat/cv/tla_cv.pkl"))

# %%
plot_ela_perspective1(ela_cv)
plot_perspective1_combined(ela_cv, tla_cv)

# %%
plot_ela_per_feature(ela_cv, config_keys=[
    "cma_random_25", "cma_random_50", "cma_random_75", "cma_random_100"
])

# %% [markdown]
# ## ELA Per function

# %%
plot_ela_cv_by_feature(ela_cv, "cma_random_25")

# %%
plot_ela_cv_by_feature(ela_cv, "cma_random_50")

# %%
plot_ela_cv_by_feature(ela_cv, "cma_random_75")

# %%
plot_ela_cv_by_feature(ela_cv, "cma_random_100")

# %% [markdown]
# ## TLA

# %%
plot_tla_per_segment(tla_cv, config_keys=["cma_random_10",
    "cma_random_25", "cma_random_50", "cma_random_75", "cma_random_100"])

# %%
plot_tla_per_transform(tla_cv, config_keys=["cma_random_10",
    "cma_random_25", "cma_random_50", "cma_random_75", "cma_random_100"])

# %%
plot_tla_per_homology(tla_cv, config_keys=["cma_random_10",
    "cma_random_25", "cma_random_50", "cma_random_75", "cma_random_100"])

# %%
plot_ela_cv_by_feature(ela_cv, "uniform_25")
