# %%
from classification_plots import *
from pathlib import Path

# %%
ela_results = load_results(Path("/Users/leekaijen/t7ssd/ela_classification_results.h5"))
tla_results = load_tla_results(Path("/Users/leekaijen/t7ssd/tla_classification_results_all.h5"))

# %%
plot_overall_accuracies(ela_results)

# %%
rank_configs(ela_results)
# Out:
#  1. sobol_100       | acc=0.8965 | cons=0.8965
#  2. ilhs_75         | acc=0.8794 | cons=0.8794
#  3. ilhs_100        | acc=0.8736 | cons=0.8736
#  4. lhs_100         | acc=0.8656 | cons=0.8656
#  5. sobol_75        | acc=0.8618 | cons=0.8618
#  6. ilhs_50         | acc=0.8503 | cons=0.8503
#  7. uniform_100     | acc=0.8453 | cons=0.8453
#  8. lhs_75          | acc=0.8446 | cons=0.8446
#  9. sobol_50        | acc=0.8363 | cons=0.8363
# 10. uniform_75      | acc=0.8338 | cons=0.8338
# 11. lhs_50          | acc=0.8032 | cons=0.8032
# 12. ilhs_25         | acc=0.8007 | cons=0.8007
# 13. uniform_50      | acc=0.7891 | cons=0.7891
# 14. sobol_25        | acc=0.7833 | cons=0.7833
# 15. lhs_25          | acc=0.7522 | cons=0.7522
# 16. uniform_25      | acc=0.7378 | cons=0.7378
# 17. cma_random_100  | acc=0.6368 | cons=0.6368
# 18. cma_random_50   | acc=0.6218 | cons=0.6218
# 19. cma_random_75   | acc=0.6209 | cons=0.6209
# 20. cma_random_25   | acc=0.5774 | cons=0.5774

# %%
plot_overall_tla_accuracies(tla_results)

# %%
rank_tla_configs(tla_results, by="overall_mean")
# Out:
#  1. ilhs_100        | acc=0.6779 | cons=0.1518
#  2. lhs_100         | acc=0.6771 | cons=0.1202
#  3. ilhs_75         | acc=0.6746 | cons=0.1282
#  4. ilhs_50         | acc=0.6721 | cons=0.1046
#  5. sobol_100       | acc=0.6721 | cons=0.1448
#  6. sobol_50        | acc=0.6721 | cons=0.0978
#  7. uniform_100     | acc=0.6700 | cons=0.1121
#  8. sobol_75        | acc=0.6646 | cons=0.1211
#  9. lhs_75          | acc=0.6625 | cons=0.0927
# 10. lhs_50          | acc=0.6504 | cons=0.0829
# 11. uniform_75      | acc=0.6496 | cons=0.0932
# 12. uniform_50      | acc=0.6367 | cons=0.0732
# 13. ilhs_25         | acc=0.6033 | cons=0.0830
# 14. sobol_25        | acc=0.5858 | cons=0.0746
# 15. cma_random_75   | acc=0.5825 | cons=0.0543
# 16. cma_random_100  | acc=0.5792 | cons=0.0572
# 17. lhs_25          | acc=0.5737 | cons=0.0625
# 18. cma_random_50   | acc=0.5604 | cons=0.0471
# 19. uniform_25      | acc=0.5150 | cons=0.0566
# 20. ilhs_10         | acc=0.4925 | cons=0.0628
# ...
