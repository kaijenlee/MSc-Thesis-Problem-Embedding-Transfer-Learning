# %%
from classfication_all_runs import *
from pathlib import Path
results = load_results(Path("/Users/leekaijen/t7ssd/ela_classification_results_allruns.h5"))

# %%
plot_accuracy_median(results)
# Out:
# <Axes: title={'center': 'Classification accuracy — testing on median features'}, ylabel='Accuracy'>

# %%
plot_accuracy_allruns(results)
# Out:
# <Axes: title={'center': 'Classification accuracy — testing on all individual runs'}, ylabel='Accuracy (averaged over runs)'>

# %%
plot_per_class_heatmap(results, metric="median")
# Out:
# <Axes: title={'center': 'Per-class accuracy (median)'}, xlabel='BBOB function'>

# %%
plot_per_class_heatmap(results, metric="all_runs")
# Out:
# <Axes: title={'center': 'Per-class accuracy (all_runs)'}, xlabel='BBOB function'>

# %%
plot_strategy_size_heatmap(results, metric="median")
# Out:
# <Axes: title={'center': 'Accuracy (median test) by strategy × size'}, xlabel='Sample size', ylabel='Sampling strategy'>

# %%
plot_strategy_size_heatmap(results, metric="all_runs")
# Out:
# <Axes: title={'center': 'Accuracy (all runs test) by strategy × size'}, xlabel='Sample size', ylabel='Sampling strategy'>
